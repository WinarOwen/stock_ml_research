# %% [markdown]
# Importing libraries

# %%
import yfinance as yf
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import ta

# %% [markdown]
# Dataset

# %%
data = yf.download("SPY",start="2025-06-01",end="2025-12-31")
print(data.head())
# Out:
# [*********************100%***********************]  1 of 1 completed
# Price            Close        High         Low        Open    Volume
# Ticker             SPY         SPY         SPY         SPY       SPY
# Date
# 2025-06-02  587.592834  587.672100  580.008857  582.685558  61630500
# 2025-06-03  590.943604  591.925047  586.740159  587.225980  63606200
# 2025-06-04  590.785034  592.787614  590.348830  591.806171  57314200
# 2025-06-05  587.929871  593.828513  585.947138  592.470346  92278700
# 2025-06-06  593.967285  595.642697  591.706941  593.491388  66588700
